# %%
import pandas as pd
import logging
import sys
import talib
import pynance
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
from src.financial_analyzer import FinancialAnalyzer
from src.correlation_analysis import SentimentCorrelationAnalyzer

# %%
google=FinancialAnalyzer('GOOG')
google.run()
# Out:
# 2026-05-11 18:16:12,155 - INFO - Successfully loaded data for GOOG Ticker
# 2026-05-11 18:16:12,175 - INFO - Successfully cleaned and standardized data for GOOG
# 2026-05-11 18:16:12,229 - INFO - Successfully used PyNance for SMA
# 2026-05-11 18:16:12,229 - INFO - Technical indicators calculated for GOOG
# 2026-05-11 18:16:12,272 - INFO - Technical sentiment and metrics calculated for GOOG
#                  Close        High         Low        Open       Volume  \
# Date
# 2009-01-02    7.948608    7.960977    7.557264    7.633949  144961322.0
# 2009-01-05    8.115089    8.194003    7.792268    7.940692  196293007.0
# 2009-01-06    8.263762    8.430492    8.074027    8.237046  257971329.0
# 2009-01-07    7.965677    8.185839    7.885034    8.121770  180453860.0
# 2009-01-08    8.044340    8.044340    7.850152    7.873406  144567852.0
# ...                ...         ...         ...         ...          ...
# 2023-12-22  141.750000  142.276397  141.089511  141.164014   18513500.0
# ...

# %%
google_sentiment=SentimentCorrelationAnalyzer('GOOG', google.df)
google_sentiment.run()
# Out:
# 2026-05-11 19:02:59,873 - INFO - Calculated daily stock returns.
# ...
# AUTOMATED INSIGHTS: GOOG SENTIMENT ANALYSIS
# ...
# 1. Correlation Analysis: A moderate positive correlation (0.1716) was found.
# 2. Return Impact: Days with Positive sentiment averaged 0.5301% returns.
# 3. Risk Context: Days with Negative sentiment averaged -0.6108% returns.
#
# CONCLUSION: Sentiment is a directionally valid leading indicator for this asset.
# ...
# 0.17164631292476507

# %% [markdown]
# ### Investment Analysis Report: GOOG (Alphabet Inc.)
# **Analysis Date:** May 11, 2026
# **Data Horizon:** 2009 – 2024
# **Current Price:** $139.97
#
# ---
#
# #### 1. Executive Summary: Technical Verdict - **STRONG BULLISH**
# Despite a marginal daily decrease of **-0.25%**, Google maintains a **Strong Bullish** technical profile. The asset has delivered a **1660.96% cumulative return** over the analyzed period. While other mega-caps are showing signs of consolidation, Google’s internal momentum remains robust, supported by a healthy and reliable sentiment-to-price correlation.
#
# ---
#
# #### 2. Technical Indicator Breakdown
# Google’s price action is defined by strong structural support and consistent upward momentum:
#
# * **MACD (Trend Momentum):** A **Bullish Crossover** is clearly in play. While the `MACD_Hist` has slightly decelerated to **0.536**, the fact that it remains positive confirms that the buyers are still in control of the primary trend.
# * **Moving Averages (SMA 20):** The price ($139.97) is trading comfortably above the **20-day SMA ($135.97)**. This ~$4 cushion acts as a significant support floor; the technical trend is considered structurally sound as long as it remains above this level.
# * **RSI (Momentum):** Currently at **59.31**, the RSI is in the ideal Expansion Zone. It has cooled enough to avoid being Overbought, suggesting there is significant runway for further price appreciation before hitting a momentum ceiling.
# * **Volatility:** The **20-Day Rolling Volatility (0.0163)** is categorized as **High** for this asset. Investors should be prepared for larger intraday swings, even while the macro trend remains upward.
#
# ---
#
# #### 3. Automated Sentiment Insights
# Google demonstrates a **moderate positive correlation (0.1716)**, indicating that sentiment is a reliable secondary confirmation tool for technical entries.
#
# | Sentiment Category | Avg. Daily Return | Investor Context |
# | :--- | :--- | :--- |
# | **Positive** | **+0.5301%** | Consistent gains observed during positive news cycles. |
# | **Negative** | **-0.6108%** | Negative news leads to clear, albeit manageable, pullbacks. |
#
# **Conclusion:** Sentiment is a **directionally valid leading indicator**. The spread between positive and negative days is roughly **1.14%**, providing a clear statistical edge for timing trades around news catalysts.
#
# ---
#
# #### 4. Stability & Visual Trends
# The historical and recent visuals highlight:
# * **The Stability Check:** Google's growth volatility has stayed within a predictable range since the 2022 recovery, showing a more mature stability profile than its high-growth peers.
# * **Verdict Consistency:** The EDA has issued a Strong Bullish rating for five consecutive sessions (Dec 22 – Dec 29), signaling high conviction in the current price levels.
#
# ---
#
# #### 5. Strategic Conclusion
# **Current Stance: BUY / HOLD**
#
# Google is currently exhibiting one of the cleanest technical setups in the sector.
# * **Tactical Entry:** The minor dip to **$139.97** is a high-probability entry point before a potential retest of the **$142.00** resistance level.
# * **Risk Management:** Keep a close watch on the **MACD Histogram**. A cross below zero would signal a shift to a Neutral or Cautionary regime.
# * **Sentiment Filter:** Given the sensitivity to negative news (-0.61%), avoid adding to positions during major regulatory or legal news cycles.
