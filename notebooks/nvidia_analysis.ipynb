# %%
import pandas as pd
import logging
import sys
import talib
import pynance.tech as pn_tech
#import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
from src.financial_analyzer import FinancialAnalyzer
from src.correlation_analysis import SentimentCorrelationAnalyzer

# %%
nvidia=FinancialAnalyzer('NVDA')
nvidia.run()
# Out:
# 2026-05-12 01:11:07,329 - INFO - Successfully loaded data for NVDA Ticker
# 2026-05-12 01:11:07,343 - INFO - Successfully cleaned and standardized data for NVDA
# 2026-05-12 01:11:07,379 - INFO - Successfully used PyNance for SMA
# 2026-05-12 01:11:07,379 - INFO - Technical indicators calculated for NVDA
# 2026-05-12 01:11:07,421 - INFO - Technical sentiment and metrics calculated for NVDA
#                 Close       High        Low       Open        Volume  \
# Date
# 2009-01-02   0.199652   0.201027   0.184294   0.184982  4.971240e+08
# 2009-01-05   0.203319   0.207904   0.195984   0.197360  7.057360e+08
# 2009-01-06   0.210196   0.216156   0.204695   0.209279  6.579040e+08
# 2009-01-07   0.197589   0.205382   0.190483   0.205382  8.700960e+08
# 2009-01-08   0.192546   0.195067   0.180626   0.195067  1.014496e+09
# ...               ...        ...        ...        ...           ...
# 2023-12-22  48.805527  49.358247  48.442706  49.170342  2.525070e+08
# ...

# %%
nvidia_sentiment = SentimentCorrelationAnalyzer('NVDA', nvidia.df)
nvidia_sentiment.run()
# Out:
# 2026-05-12 01:12:13,567 - INFO - Calculated daily stock returns.
# ...
# AUTOMATED INSIGHTS: NVDA SENTIMENT ANALYSIS
# ...
# 1. Correlation Analysis: A moderate positive correlation (0.2132) was found.
# 2. Return Impact: Days with Positive sentiment averaged 0.7845% returns.
# 3. Risk Context: Days with Negative sentiment averaged -1.4698% returns.
#
# CONCLUSION: Sentiment is a directionally valid leading indicator for this asset.
# ...
# 0.21319930594762296

# %% [markdown]
# ### Investment Analysis Report: NVDA (NVIDIA Corp.)
# **Analysis Date:** May 12, 2026
# **Data Horizon:** 2009 – 2024
# **Current Price:** $49.50
#
# ---
#
# #### 1. Executive Summary: Technical Verdict - **STRONG BULLISH**
# NVIDIA concludes the series with a **Strong Bullish** profile. The stock is exhibiting classic blue chip momentum, maintaining its bullish regime for five consecutive sessions through the end of December 2023. With a staggering historical return, the asset remains the primary vehicle for growth within the semiconductor and AI sectors.
#
# ---
#
# #### 2. Technical Indicator Breakdown
# The technical structure for NVDA is characterized by steady accumulation and low-volatility upward drift:
#
# * **Price vs. SMA 20:** The current price ($49.50) is comfortably above the **20-Day SMA ($48.05)**. This indicates that the short-term trend is well-supported and the simplest path remains upward.
# * **MACD (Trend Momentum):** A **Bullish Crossover** is active. While the `MACD_Hist` slowed slightly to **0.062** on the final day, the MACD line ($0.69) remains above the Signal line ($0.63). This suggests that while the momentum is stabilizing, the bullish trend hasn't broken.
# * **RSI (Momentum):** At **58.31**, NVDA is in a healthy Neutral-Bullish zone. It is far from the Overbought threshold (70+), meaning there is significant structural room for the price to run higher before a momentum-driven pullback is necessary.
# * **Volatility:** The **20-Day Rolling Volatility is Low (0.0173)**. For a high-growth stock like NVIDIA, this level of volatility is remarkably controlled, suggesting institutional accumulation rather than retail speculation.
#
# ---
#
# #### 3. Automated Sentiment Insights
# NVDA shows a **moderate positive correlation (0.2132)** with news sentiment, indicating that headlines serve as a significant catalyst for price action.
#
# | Sentiment Category | Avg. Daily Return | Risk Context |
# | :--- | :--- | :--- |
# | **Positive** | **+0.7845%** | Strong response to positive product or AI-sector news. |
# | **Negative** | **-1.4698%** | **Asymmetric Risk.** Negative news impacts the stock nearly twice as much as positive news. |
#
# **Conclusion:** Sentiment is a **directionally valid leading indicator**. Investors should be particularly wary of News Spikes to the downside; given NVDA's high valuation, negative news often triggers sharp, high-volume profit-taking.
#
# ---
#
# #### 4. Visual Stability & Trend Analysis
# The visuals highlight:
# * **The Squeeze:** The Bollinger Band visuals show the price hugging the upper band, a sign of a strong, persistent trend.
# * **Historical Alpha:** The cumulative return chart (24,691%) dwarfs its peers, illustrating the power of the semiconductor cycle over the last decade.
#
# ---
#
# #### 5. Strategic Conclusion
# **Current Stance: BUY / ACCUMULATE**
#
# NVIDIA remains a leader in momentum and technical strength.
# * **Technical Trigger:** As long as the price maintains its position above the **$48.00 (SMA 20)** level, the Strong Bullish outlook remains intact.
# * **Risk Management:** Watch for a crossover in the **MACD Histogram** below zero. Such a shift would signal the first sign of a meaningful consolidation phase.
# * **Sentiment Play:** Use positive AI-sector headlines as a confirmation for adding to positions, but maintain tight stop-losses given the **-1.47% sensitivity** to negative sentiment.
