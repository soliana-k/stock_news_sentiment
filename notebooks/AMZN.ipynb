# %%
import pandas as pd
import logging
import sys
import talib
import pynance
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
from src.financial_analyzer import FinancialAnalyzer

# %%
amazon=FinancialAnalyzer('AMZN')
amazon.run()
# Out:
# 2026-05-08 14:27:02,521 - INFO - Successfully loaded data for AMZN Ticker
# 2026-05-08 14:27:02,538 - INFO - Successfully cleaned and standardized data for AMZN
# 2026-05-08 14:27:02,574 - INFO - Successfully used PyNance for SMA
# 2026-05-08 14:27:02,576 - INFO - Technical indicators calculated for AMZN
#                  Close        High         Low        Open       Volume  \
# Date
# 2009-01-02    2.718000    2.726500    2.553500    2.567500  145928000.0
# 2009-01-05    2.703000    2.787000    2.651500    2.786500  190196000.0
# 2009-01-06    2.868000    2.911000    2.687500    2.727500  221602000.0
# 2009-01-07    2.810000    2.847500    2.767500    2.814500  158854000.0
# 2009-01-08    2.858000    2.866000    2.729000    2.749500  131558000.0
# ...                ...         ...         ...         ...          ...
# 2023-12-22  153.419998  154.350006  152.710007  153.770004   29514100.0
# 2023-12-26  153.410004  153.979996  153.029999  153.559998   25067200.0
# 2023-12-27  153.339996  154.779999  153.119995  153.559998   31434700.0
# 2023-12-28  153.380005  154.080002  152.949997  153.720001   27057000.0
# 2023-12-29  151.940002  153.889999  151.029999  153.100006   39823200.0
#
#                 SMA_20      EMA_20        RSI      MACD  MACD_Signal  \
# Date
# 2009-01-02         NaN         NaN        NaN       NaN          NaN
# 2009-01-05         NaN         NaN        NaN       NaN          NaN
# 2009-01-06         NaN         NaN        NaN       NaN          NaN
# 2009-01-07         NaN         NaN        NaN       NaN          NaN
# 2009-01-08         NaN         NaN        NaN       NaN          NaN
# ...                ...         ...        ...       ...          ...
# 2023-12-22  148.578999  148.860492  64.115558  3.135958     2.873052
# 2023-12-26  148.863000  149.293779  64.085644  3.118650     2.922172
# 2023-12-27  149.178500  149.679133  63.860893  3.063965     2.950530
# 2023-12-28  149.531499  150.031597  63.938728  2.989395     2.958303
# 2023-12-29  149.824000  150.213350  59.012257  2.782032     2.923049
#
#             MACD_Hist     PyN_SMA
# Date
# 2009-01-02        NaN         NaN
# 2009-01-05        NaN         NaN
# 2009-01-06        NaN         NaN
# 2009-01-07        NaN         NaN
# 2009-01-08        NaN         NaN
# ...               ...         ...
# 2023-12-22   0.262905  148.578999
# 2023-12-26   0.196478  148.863000
# 2023-12-27   0.113434  149.178500
# 2023-12-28   0.031092  149.531499
# 2023-12-29  -0.141017  149.824000
#
# [3774 rows x 12 columns]
# 2026-05-08 14:27:16,973 - INFO - Technical sentiment and metrics calculated for AMZN
# Date
# 2009-01-02           Neutral
# 2009-01-05           Neutral
# 2009-01-06           Neutral
# 2009-01-07           Neutral
# 2009-01-08           Neutral
#                    ...
# 2023-12-22    Strong Bullish
# 2023-12-26    Strong Bullish
# 2023-12-27    Strong Bullish
# 2023-12-28    Strong Bullish
# 2023-12-29           Neutral
# Name: Technical_Verdict, Length: 3774, dtype: object
# --------------------------------------------------
# INVESTMENT INSIGHTS FOR: AMZN
# --------------------------------------------------
# Current Price: $151.94 (-0.94%)
# Technical Verdict: NEUTRAL
#
# --- Indicator Breakdown ---
# • RSI: 59.01 (Neutral)
# • Trend: Above 20-Day SMA
# • MACD: Bearish Crossover
#
# --- Risk Profile ---
# • 20-Day Rolling Volatility: 0.0119 (Low)
# • Cumulative Return (Period): 5490.14%
# --------------------------------------------------
