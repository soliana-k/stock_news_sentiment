# %%
import pandas as pd
import logging
import sys
import talib
import pynance
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
from src.financial_analyzer import FinancialAnalyzer
from src.correlation_analysis import SentimentCorrelationAnalyzer

# %%
meta=FinancialAnalyzer('META')
meta.run()
# Out:
# 2026-05-11 19:10:36,561 - INFO - Successfully loaded data for META Ticker
# 2026-05-11 19:10:36,568 - INFO - Successfully cleaned and standardized data for META
# 2026-05-11 19:10:36,618 - INFO - Successfully used PyNance for SMA
# 2026-05-11 19:10:36,618 - INFO - Technical indicators calculated for META
# 2026-05-11 19:10:36,658 - INFO - Technical sentiment and metrics calculated for META
#                  Close        High         Low        Open       Volume  \
# Date
# 2012-05-18   37.995762   44.724282   37.767172   41.792356  573576400.0
# 2012-05-21   33.821495   36.435382   32.797807   36.306177  168192700.0
# 2012-05-22   30.810066   33.384198   30.750434   32.410203  101786600.0
# 2012-05-23   31.803938   32.300874   31.167860   31.177799   73600000.0
# 2012-05-24   32.827625   33.006523   31.575347   32.748117   50237200.0
# ...                ...         ...         ...         ...          ...
# 2023-12-22  351.224823  355.011477  349.068105  353.401377   11772800.0
# ...

# %%
meta_sentiment=SentimentCorrelationAnalyzer('FB', meta.df)
meta_sentiment.run()
# Out:
# 2026-05-11 19:21:44,165 - INFO - Calculated daily stock returns.
# ...
# AUTOMATED INSIGHTS: FB SENTIMENT ANALYSIS
# ...
# 1. Correlation Analysis: A strong positive correlation (0.4389) was found.
# 2. Return Impact: Days with Positive sentiment averaged 1.8696% returns.
# 3. Risk Context: Days with Negative sentiment averaged -2.6035% returns.
#
# CONCLUSION: Sentiment is a directionally valid leading indicator for this asset.
# ...
# 0.43893054274518395

# %% [markdown]
# ### Investment Analysis Report: META (formerly FB)
# **Analysis Date:** May 11, 2026
# **Ticker Context:** Financials analyzed as **META** | Sentiment analyzed as **FB** **Current Price:** $351.79
#
# ---
#
# #### 1. Executive Summary: Technical Verdict - **STRONG BULLISH**
# Despite a minor daily dip of **-1.22%**, Meta Platforms maintains a powerhouse technical profile. The asset has achieved an **825.87% cumulative return** since its 2012 inception and currently sits firmly in a Strong Bullish regime. Unlike other tech giants where sentiment often acts as noise, Meta demonstrates a rare, high-conviction link between news cycles and price action.
#
# ---
#
# #### 2. Technical Indicator Breakdown
# Meta’s technical structure remains robust, supported by strong trend-following signals:
#
# * **MACD (Trend Momentum):** The **Bullish Crossover** is the standout feature. Even with the slight price pullback on 2023-12-29, the `MACD_Hist` remains positive (**1.499**), indicating that upward momentum is still dominant over the long-term signal.
# * **Moving Averages:** The price ($351.79) is trading significantly above its **SMA_20 ($336.87)**. This ~$15 cushion indicates a well-established uptrend that is not easily broken by short-term volatility.
# * **RSI (Momentum):** At **64.30**, the RSI has cooled down from Overbought levels (it touched **70.23** on Dec 28). This is a healthy reset that prevents the stock from being overextended, allowing for more sustainable growth.
# * **Volatility:** The **20-Day Rolling Volatility (0.0146)** is low, suggesting that current price movements are controlled and part of a steady accumulation phase rather than erratic speculation.
#
# ---
#
# #### 3. High-Impact Sentiment Analysis
# Meta represents one of the strongest Sentiment-to-Price correlations in the tech sector.
#
# | Metric | Value | Interpretation |
# | :--- | :--- | :--- |
# | **Pearson Correlation** | **0.4389** | **Strong Positive.** Significantly higher than peer mega-caps. |
# | **Positive Sentiment Impact** | **+1.8696%** | Positive news cycles generate nearly 2% daily outperformance. |
# | **Negative Sentiment Risk** | **-2.6035%** | **High Fragility.** Negative news causes sharp, significant sell-offs. |
#
# **Strategic Insight:** The **0.4389 correlation** suggests that for Meta, the news is a primary driver of liquidity and direction. The wide gap between positive and negative returns identifies Meta as a high-beta asset regarding public and regulatory perception.
#
# ---
#
# #### 4. Stability & Visual Trends
# The historical visuals confirm a highly consistent growth trajectory:
# * **Bollinger Band Interaction:** Current price action shows the asset riding the upper band, a classic sign of a strong trending market.
# * **Regime Stability:** The Technical Verdict history shows Meta has maintained a **Strong Bullish** status for the final week of December, suggesting institutional backing during the year-end close.
#
# ---
#
# #### 5. Strategic Conclusion
# **Current Stance: BUY / ACCUMULATE ON DIPS**
#
# Meta is currently a Sentiment Leader.
# * **Buy Trigger:** The current price dip to **$351.79** is a technical entry opportunity, as it provides a better risk-reward ratio while the trend remains **Strong Bullish.**
# * **Risk Watch:** Monitor news headlines closely. Given the **-2.6% impact** of negative sentiment, any regulatory or privacy-related news will likely break the current SMA_20 support.
# * **Profit Target:** As long as the **MACD Histogram** stays above zero, the path of least resistance remains upward.
