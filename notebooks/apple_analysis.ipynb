# %%
import pandas as pd
import logging
import sys
import talib
import pynance.tech as pn_tech
#import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)
# %load_ext autoreload
# %autoreload 2

# %%
from src.financial_analyzer import FinancialAnalyzer
from src.correlation_analysis import SentimentCorrelationAnalyzer

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %reload_ext autoreload

# %%
apple=FinancialAnalyzer('AAPL')
apple.run()
# Out:
# 2026-05-11 23:18:25,185 - INFO - Successfully loaded data for AAPL Ticker
# 2026-05-11 23:18:25,203 - INFO - Successfully cleaned and standardized data for AAPL
# 2026-05-11 23:18:25,251 - INFO - Successfully used PyNance for SMA
# 2026-05-11 23:18:25,251 - INFO - Technical indicators calculated for AAPL
# 2026-05-11 23:18:25,283 - INFO - Technical sentiment and metrics calculated for AAPL
#                  Close        High         Low        Open        Volume  \
# Date
# 2009-01-02    2.721686    2.730385    2.554037    2.575630  7.460152e+08
# 2009-01-05    2.836553    2.884539    2.780469    2.794266  1.181608e+09
# 2009-01-06    2.789767    2.914229    2.770872    2.877641  1.289310e+09
# 2009-01-07    2.729484    2.774170    2.706990    2.753477  7.530488e+08
# 2009-01-08    2.780169    2.793666    2.700393    2.712090  6.735008e+08
# ...                ...         ...         ...         ...           ...
# ...

# %%
apple_sentiment = SentimentCorrelationAnalyzer('AAPL', apple.df)
apple_sentiment.run()
# Out:
# 2026-05-11 23:18:46,134 - INFO - Calculated daily stock returns.
# ...
# AUTOMATED INSIGHTS: AAPL SENTIMENT ANALYSIS
# ...
# 1. Correlation Analysis: A very weak positive correlation (0.0854) was found.
# 2. Return Impact: Days with Positive sentiment averaged 0.6980% returns.
# 3. Risk Context: Days with Negative sentiment averaged -1.7323% returns.
#
# CONCLUSION: Sentiment is a directionally valid leading indicator for this asset.
# ...
# 0.0853642758880789

# %% [markdown]
# ### Investment Analysis Report: AAPL (Apple Inc.)
# **Analysis Date:** May 12, 2026
# **Data Horizon:** 2009 – 2024
# **Current Price:** $190.73
#
# ---
#
# #### 1. Executive Summary: Technical Verdict - **STRONG BEARISH**
# Despite its legendary long-term performance, Apple has entered a **Strong Bearish** phase as of late December 2023. The model has flagged five consecutive Strong Bearish sessions. While the price remains stable, the underlying momentum indicators suggest that the stock is struggling to maintain its recent highs, entering a period of distribution.
#
# ---
#
# #### 2. Technical Indicator Breakdown
# The Strong Bearish verdict is driven by a breakdown in trend and momentum symmetry:
#
# * **Price vs. SMA 20:** The current price ($190.73) has slipped below the **20-Day SMA ($192.49)**. In technical analysis, trading below this moving average often signals that the short-term trend has shifted from support to resistance.
# * **MACD (Trend Momentum):** I am seeing a confirmed **Bearish Crossover**. The MACD line ($1.55) is trending significantly below the Signal line ($2.42), and the `MACD_Hist` is deeply negative at **-0.865**, indicating accelerating downward pressure.
# * **RSI (Momentum):** Currently at **51.12**, the RSI is in unclaimed region. It isn't oversold enough to trigger a buy the dip reflex, nor strong enough to suggest a recovery. It reflects a total loss of the bullish enthusiasm seen earlier in the month.
# * **Volatility:** The **20-Day Rolling Volatility is Low (0.0091)**. This suggests that the current decline isn't a panic sell-off, but rather a slow, steady bleed out of positions.
#
# ---
#
# #### 3. Automated Sentiment Insights
# Apple demonstrates a **very weak positive correlation (0.0854)**, suggesting that technical factors and macro flows currently outweigh news headlines for this asset.
#
# | Sentiment Category | Avg. Daily Return | Risk Context |
# | :--- | :--- | :--- |
# | **Positive** | **+0.6980%** | Mild gains; the stock is less reactive to hype than peers. |
# | **Negative** | **-1.7323%** | **High Impact.** Bad news hits twice as hard as good news helps. |
#
# **Conclusion:** Sentiment is a Directionally Valid indicator but requires caution. While the correlation is low, the **Risk Context** shows that Apple is highly sensitive to negative catalysts, which could act as a trapdoor for the current bearish technical setup.
#
# ---
#
# #### 4. Stability & Visual Trends
# The visuals confirm:
# * **The Stability Check:** Apple remains the gold standard for stability, with its growth volatility remaining the lowest among the big tech cohort analyzed so far.
# * **Trend Exhaustion:** The visuals show the price failing to stay above the upper Bollinger Band, drifting back toward the midline, a classic sign of trend exhaustion.
#
# ---
#
# #### 5. Strategic Conclusion
# **Current Stance: CAUTION / AWAIT SUPPORT**
#
# Apple is currently underwater relative to its short-term trend.
# * **Defensive Strategy:** Do not attempt to buy a stock that is rapidly declining in price, hoping to profit from a rebound until the price reclaims the **$192.50 (SMA 20)** level on high volume.
# * **Support Watch:** Look for a bounce near previous psychological support levels. If the **MACD Histogram** continues to widen in the negative direction, expect further testing of lower price targets.
# * **Sentiment Warning:** Given the **-1.73% impact** of negative news, any surprise bearish headlines during this weak technical window could trigger a sharper correction.
